# %%
# !pip install ru_accent_poet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ru_accent_poet in /usr/local/lib/python3.7/dist-packages (0.1.5)
# Requirement already satisfied: russtress in /usr/local/lib/python3.7/dist-packages (from ru_accent_poet) (0.1.4)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from ru_accent_poet) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->ru_accent_poet) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->ru_accent_poet) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->ru_accent_poet) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.21.0->ru_accent_poet) (1.24.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from russtress->ru_accent_poet) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from russtress->ru_accent_poet) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from russtress->ru_accent_poet) (1.7.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (4.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (57.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (14.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (0.26.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (0.5.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (2.8.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (1.47.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (1.1.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (2.8.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (3.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->russtress->ru_accent_poet) (1.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->russtress->ru_accent_poet) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->russtress->ru_accent_poet) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->russtress->ru_accent_poet) (3.2.0)

# %%
from ru_accent_poet import accent_line
import ru_accent_poet as accent

# %%
import os
import re 
import shutil

# %%
print(accent_line("двенадцать-восемнадцать"))
print(accent_line("двенадцать - восемнадцать"))
# Out:
# двенадцать-восемнадца'ть
# двена'дцать - восемна'дцать

# %%
accent_line('  «Мой дядя самых честных правил,\nКогда не в шутку занемог,\nОн уважать себя заставил\nИ лучше выдумать не мог.\nЕго пример другим наука;\nНо, боже мой, какая скука\nС больным сидеть и день и ночь,\nНе отходя ни шагу прочь!\nКакое низкое коварство\nПолуживого забавлять,\nЕму подушки поправлять,\nПечально подносить лекарство,\nВздыхать и думать про себя:\nКогда же черт возьмет тебя!»')
# Out:
# "«Мой дя'дя са'мых че'стных пра'вил, Когда' не в шу'тку занемо'г, Он уважа'ть себя' заста'вил И лу'чше вы'думать не мог. Его' приме'р други'м нау'ка; Но, бо'же мой, кака'я ску'ка С больны'м сиде'ть и день и ночь, Не отходя' ни ша'гу прочь! Како'е ни'зкое кова'рство Полуживо'го забавля'ть, Ему' поду'шки поправля'ть, Печа'льно подноси'ть лека'рство, Вздыха'ть и ду'мать про себя': Когда' же черт возьмёт тебя'!»"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
# test for right path

for path, y, files in os.walk('/content/drive/MyDrive/Colab Notebooks/corpus35/texts_stressed'):
  for f in files[1:10]:
    print(f)
# Out:
# P_295.txt
# P_1737.txt
# P_281.txt
# P_1051.txt
# P_242.txt
# P_256.txt
# P_1045.txt
# P_1079.txt
# P_1723.txt

# %%
for path, y, files in os.walk('/content/drive/MyDrive/Colab Notebooks/corpus35/texts_stressed'):
  for f in files:
    print(f)
    accent.write_file([os.path.join(path, f)])
# Out:
# P_1284.txt
# P_295.txt
# P_1737.txt
# P_281.txt
# P_1051.txt
# P_242.txt
# P_256.txt
# P_1045.txt
# P_1079.txt
# P_1723.txt
# P_1086.txt
# P_1092.txt
# P_1290.txt
# P_1520.txt
# P_451.txt
# P_323.txt
# P_445.txt
# P_1130.txt
# P_1124.txt
# P_31.txt
# P_1656.txt
# P_1642.txt
# P_900.txt
# P_653.txt
# P_135.txt
# P_1643.txt
# P_30.txt
# P_1657.txt
# P_1125.txt
# P_1131.txt
# P_336.txt
# P_444.txt
# P_322.txt
# P_647.txt
# P_1326.txt
# P_1332.txt
# P_874.txt
# P_1695.txt
# P_1440.txt
# P_1468.txt
# P_19.txt
# P_1454.txt
# P_121.txt
# P_479.txt
# P_1681.txt
# P_25.txt
# P_1327.txt
# P_875.txt
# P_1469.txt
# P_18.txt
# P_1333.txt
# P_1455.txt
# P_1694.txt
# P_1441.txt
# P_337.txt
# P_492.txt
# P_486.txt
# P_487.txt
# P_24.txt
# P_493.txt
# P_1253.txt
# P_929.txt
# P_901.txt
# P_915.txt
# P_1521.txt
# P_1509.txt
# P_1247.txt
# P_1535.txt
# P_1680.txt
# P_450.txt
# P_478.txt
# P_120.txt
# P_134.txt
# P_1496.txt
# P_108.txt
# P_484.txt
# P_453.txt
# P_447.txt
# P_33.txt
# P_1640.txt
# P_335.txt
# P_1126.txt
# P_27.txt
# P_321.txt
# P_1654.txt
# P_1132.txt
# P_902.txt
# P_1244.txt
# P_1250.txt
# P_1287.txt
# P_1522.txt
# P_916.txt
# P_1536.txt
# P_1293.txt
# P_1697.txt
# P_309.txt
# P_1324.txt
# P_1330.txt
# P_137.txt
# P_1442.txt
# P_876.txt
# P_862.txt
# P_1456.txt
# P_889.txt
# P_1683.txt
# P_1318.txt
# P_123.txt
# P_255.txt
# P_1052.txt
# P_241.txt
# P_1085.txt
# P_1734.txt
# P_1046.txt
# P_269.txt
# P_1091.txt
# P_1495.txt
# P_1722.txt
# P_1050.txt
# P_1078.txt
# P_294.txt
# P_1044.txt
# P_1736.txt
# P_257.txt
# P_280.txt
# P_1481.txt
# P_1278.txt
# P_282.txt
# P_296.txt
# P_1708.txt
# P_1534.txt
# P_914.txt
# P_1246.txt
# P_1497.txt
# P_1508.txt
# P_928.txt
# P_1252.txt
# P_109.txt
# P_1720.txt
# P_1087.txt
# P_519.txt
# P_1093.txt
# P_1285.txt
# P_243.txt
# P_1291.txt
# P_733.txt
# P_1057.txt
# P_1043.txt
# P_1725.txt
# P_1094.txt
# P_1719.txt
# P_293.txt
# P_1080.txt
# P_244.txt
# P_287.txt
# P_278.txt
# P_1731.txt
# P_250.txt
# P_1090.txt
# P_903.txt
# P_122.txt
# P_136.txt
# P_1523.txt
# P_1279.txt
# P_1480.txt
# P_1494.txt
# P_1245.txt
# P_268.txt
# P_1735.txt
# P_297.txt
# P_283.txt
# P_1053.txt
# P_1709.txt
# P_1047.txt
# P_1292.txt
# P_1721.txt
# P_1084.txt
# P_254.txt
# P_240.txt
# P_1286.txt
# P_1696.txt
# P_1319.txt
# P_320.txt
# P_1457.txt
# P_308.txt
# P_877.txt
# P_32.txt
# P_1682.txt
# P_917.txt
# P_1669.txt
# P_1655.txt
# P_1127.txt
# P_490.txt
# P_491.txt
# P_1641.txt
# P_485.txt
# P_1133.txt
# P_1537.txt
# P_1251.txt
# P_888.txt
# P_1443.txt
# P_1325.txt
# P_1331.txt
# P_446.txt
# P_452.txt
# P_26.txt
# P_334.txt
# P_1668.txt
# P_1268.txt
# P_133.txt
# P_1485.txt
# P_1254.txt
# P_443.txt
# P_1320.txt
# P_1452.txt
# P_872.txt
# P_37.txt
# P_325.txt
# P_1446.txt
# P_1334.txt
# P_1491.txt
# P_330.txt
# P_22.txt
# P_481.txt
# P_318.txt
# P_495.txt
# P_1692.txt
# P_1679.txt
# P_1686.txt
# P_1308.txt
# P_23.txt
# P_331.txt
# P_319.txt
# P_1693.txt
# P_494.txt
# P_1678.txt
# P_480.txt
# P_1644.txt
# P_1136.txt
# P_1122.txt
# P_457.txt
# P_1321.txt
# P_1490.txt
# P_873.txt
# P_1447.txt
# P_1335.txt
# P_1309.txt
# P_683.txt
# P_1453.txt
# P_1687.txt
# P_1137.txt
# P_1651.txt
# P_1645.txt
# P_1123.txt
# P_913.txt
# P_1269.txt
# P_907.txt
# P_1527.txt
# P_1241.txt
# P_898.txt
# P_1255.txt
# P_1533.txt
# P_456.txt
# P_442.txt
# P_36.txt
# P_324.txt
# P_1484.txt
# P_654.txt
# P_132.txt
# P_126.txt
# P_1296.txt
# P_1282.txt
# P_1647.txt
# P_1646.txt
# P_904.txt
# P_1256.txt
# P_938.txt
# P_1242.txt
# P_1524.txt
# P_1295.txt
# P_1281.txt
# P_1518.txt
# P_441.txt
# P_1652.txt
# P_455.txt
# P_1042.txt
# P_1730.txt
# P_1081.txt
# P_1724.txt
# P_292.txt
# P_1056.txt
# P_1718.txt
# P_286.txt
# P_333.txt
# P_1444.txt
# P_1322.txt
# P_1487.txt
# P_1336.txt
# P_1493.txt
# P_119.txt
# P_1478.txt
# P_1450.txt
# P_21.txt
# P_125.txt
# P_253.txt
# P_1083.txt
# P_290.txt
# P_1097.txt
# P_1068.txt
# P_284.txt
# P_247.txt
# P_509.txt
# P_131.txt
# P_1530.txt
# P_1054.txt
# P_910.txt
# P_127.txt
# P_906.txt
# P_1532.txt
# P_912.txt
# P_1526.txt
# P_899.txt
# P_1240.txt
# P_655.txt
# P_1732.txt
# P_1726.txt
# P_1040.txt
# P_251.txt
# P_245.txt
# P_1095.txt
# P_279.txt
# P_1297.txt
# P_1283.txt
# P_1350.txt
# P_751.txt
# P_989.txt
# P_745.txt
# P_1026.txt
# P_1032.txt
# P_1768.txt
# P_221.txt
# P_1581.txt
# P_235.txt
# P_1740.txt
# P_1754.txt
# P_911.txt
# P_939.txt
# P_1294.txt
# P_1531.txt
# P_1525.txt
# P_1243.txt
# P_1519.txt
# P_905.txt
# P_1595.txt
# P_209.txt
# P_1797.txt
# P_1783.txt
# P_1727.txt
# P_291.txt
# P_252.txt
# P_1096.txt
# P_285.txt
# P_508.txt
# P_1082.txt
# P_1069.txt
# P_1479.txt
# P_1337.txt
# P_1486.txt
# P_871.txt
# P_1445.txt
# P_118.txt
# P_1323.txt
# P_1451.txt
# P_246.txt
# P_1041.txt
# P_1733.txt
# P_1055.txt
# P_1280.txt
# P_483.txt
# P_497.txt
# P_1848.txt
# P_468.txt
# P_34.txt
# P_1690.txt
# P_440.txt
# P_1684.txt
# P_1257.txt
# P_130.txt
# P_124.txt
# P_35.txt
# P_482.txt
# P_327.txt
# P_496.txt
# P_1691.txt
# P_469.txt
# P_1685.txt
# P_1134.txt
# P_1492.txt
# P_454.txt
# P_1135.txt
# P_20.txt
# P_332.txt
# P_1653.txt
# P_326.txt
# P_1769.txt
# P_1794.txt
# P_1755.txt
# P_1543.txt
# P_988.txt
# P_977.txt
# P_1557.txt
# P_963.txt
# P_1392.txt
# P_750.txt
# P_744.txt
# P_1580.txt
# P_1147.txt
# P_91.txt
# P_85.txt
# P_84.txt
# P_1608.txt
# P_1609.txt
# P_1153.txt
# P_1621.txt
# P_1594.txt
# P_1386.txt
# P_156.txt
# P_142.txt
# P_1345.txt
# P_1379.txt
# P_354.txt
# P_1812.txt
# P_1190.txt
# P_181.txt
# P_1423.txt
# P_1184.txt
# P_1813.txt
# P_355.txt
# P_433.txt
# P_1185.txt
# P_1807.txt
# P_47.txt
# P_1191.txt
# P_427.txt
# P_1351.txt
# P_46.txt
# P_1437.txt
# P_340.txt
# P_426.txt
# P_1146.txt
# P_1806.txt
# P_1436.txt
# P_1542.txt
# P_976.txt
# P_1387.txt
# P_1393.txt
# P_1556.txt
# P_962.txt
# P_157.txt
# P_1635.txt
# P_1620.txt
# P_1634.txt
# P_341.txt
# P_180.txt
# P_1378.txt
# P_1344.txt
# P_1622.txt
# P_425.txt
# P_343.txt
# P_1811.txt
# P_357.txt
# P_1805.txt
# P_431.txt
# P_45.txt
# P_1838.txt
# P_1192.txt
# P_418.txt
# P_1409.txt
# P_424.txt
# P_1186.txt
# P_78.txt
# P_342.txt
# P_79.txt
# P_1193.txt
# P_1144.txt
# P_1636.txt
# P_93.txt
# P_86.txt
# P_44.txt
# P_1145.txt
# P_1179.txt
# P_87.txt
# P_1637.txt
# P_1623.txt
# P_92.txt
# P_1178.txt
# P_356.txt
# P_1569.txt
# P_1384.txt
# P_1390.txt
# P_140.txt
# P_168.txt
# P_1541.txt
# P_949.txt
# P_961.txt
# P_430.txt
# P_1810.txt
# P_1743.txt
# P_1031.txt
# P_1596.txt
# P_1025.txt
# P_1757.txt
# P_222.txt
# P_1582.txt
# P_1019.txt
# P_1804.txt
# P_1435.txt
# P_1353.txt
# P_1233.txt
# P_1347.txt
# P_1421.txt
# P_208.txt
# P_1741.txt
# P_220.txt
# P_1033.txt
# P_1027.txt
# P_1796.txt
# P_234.txt
# P_1782.txt
# P_154.txt
# P_975.txt
# P_746.txt
# P_752.txt
# P_236.txt
# P_550.txt
# P_1780.txt
# P_1030.txt
# P_1795.txt
# P_1756.txt
# P_1742.txt
# P_223.txt
# P_1024.txt
# P_237.txt
# P_1781.txt
# P_435.txt
# P_1424.txt
# P_804.txt
# P_1342.txt
# P_1236.txt
# P_145.txt
# P_1550.txt
# P_179.txt
# P_970.txt
# P_151.txt
# P_1544.txt
# P_1381.txt
# P_1418.txt
# P_1578.txt
# P_1395.txt
# P_958.txt
# P_582.txt
# P_757.txt
# P_1034.txt
# P_1746.txt
# P_1020.txt
# P_743.txt
# P_1008.txt
# P_1752.txt
# P_1587.txt
# P_948.txt
# P_1232.txt
# P_1540.txt
# P_747.txt
# P_974.txt
# P_960.txt
# P_1568.txt
# P_1554.txt
# P_1593.txt
# P_1785.txt
# P_1791.txt
# P_541.txt
# P_227.txt
# P_1346.txt
# P_1408.txt
# P_1352.txt
# P_182.txt
# P_1420.txt
# P_1434.txt
# P_1839.txt
# P_155.txt
# P_1018.txt
# P_1597.txt
# P_1583.txt
# P_1391.txt
# P_169.txt
# P_1385.txt
# P_753.txt
# P_419.txt
# P_141.txt
# P_1187.txt
# P_230.txt
# P_1786.txt
# P_1035.txt
# P_1425.txt
# P_178.txt
# P_193.txt
# P_1394.txt
# P_1357.txt
# P_1419.txt
# P_1343.txt
# P_187.txt
# P_1753.txt
# P_1747.txt
# P_1579.txt
# P_971.txt
# P_742.txt
# P_756.txt
# P_1237.txt
# P_1592.txt
# P_959.txt
# P_1551.txt
# P_352.txt
# P_434.txt
# P_68.txt
# P_40.txt
# P_97.txt
# P_1828.txt
# P_1196.txt
# P_1182.txt
# P_1021.txt
# P_965.txt
# P_1545.txt
# P_144.txt
# P_150.txt
# P_1380.txt
# P_1431.txt
# P_1140.txt
# P_1632.txt
# P_96.txt
# P_1633.txt
# P_1626.txt
# P_1829.txt
# P_82.txt
# P_1168.txt
# P_346.txt
# P_420.txt
# P_1800.txt
# P_1815.txt
# P_353.txt
# P_1801.txt
# P_347.txt
# P_1430.txt
# P_421.txt
# P_1356.txt
# P_41.txt
# P_1814.txt
# P_1169.txt
# P_83.txt
# P_1141.txt
# P_1627.txt
# P_1197.txt
# P_1183.txt
# P_69.txt
# P_153.txt
# P_1340.txt
# P_1426.txt
# P_344.txt
# P_42.txt
# P_1341.txt
# P_1433.txt
# P_1816.txt
# P_422.txt
# P_1427.txt
# P_350.txt
# P_351.txt
# P_1195.txt
# P_57.txt
# P_423.txt
# P_1817.txt
# P_437.txt
# P_345.txt
# P_1803.txt
# P_8.txt
# P_43.txt
# P_1181.txt
# P_80.txt
# P_1618.txt
# P_1624.txt
# P_81.txt
# P_1142.txt
# P_95.txt
# P_1631.txt
# P_1143.txt
# P_1619.txt
# P_1625.txt
# P_973.txt
# P_1235.txt
# P_146.txt
# P_1553.txt
# P_1396.txt
# P_152.txt
# P_1547.txt
# P_1382.txt
# P_94.txt
# P_1180.txt
# P_1630.txt
# P_1779.txt
# P_998.txt
# P_1584.txt
# P_1023.txt
# P_1037.txt
# P_754.txt
# P_1745.txt
# P_1751.txt
# P_1194.txt
# P_9.txt
# P_1802.txt
# P_1355.txt
# P_185.txt
# P_1369.txt
# P_1009.txt
# P_583.txt
# P_1784.txt
# P_226.txt
# P_224.txt
# P_568.txt
# P_1790.txt
# P_232.txt
# P_191.txt
# P_967.txt
# P_1209.txt
# P_1590.txt
# P_768.txt
# P_1792.txt
# P_218.txt
# P_1628.txt
# P_1600.txt
# P_1832.txt
# P_1629.txt
# P_66.txt
# P_348.txt
# P_1417.txt
# P_1577.txt
# P_176.txt
# P_1239.txt
# P_1365.txt
# P_1371.txt
# P_162.txt
# P_1403.txt
# P_231.txt
# P_228.txt
# P_1787.txt
# P_200.txt
# P_225.txt
# P_572.txt
# P_219.txt
# P_214.txt
# P_1359.txt
# P_957.txt
# P_1211.txt
# P_1563.txt
# P_764.txt
# P_770.txt
# P_980.txt
# P_994.txt
# P_1749.txt
# P_758.txt
# P_1588.txt
# P_1205.txt
# P_943.txt
# P_755.txt
# P_1208.txt
# P_966.txt
# P_999.txt
# P_1036.txt
# P_769.txt
# P_1591.txt
# P_1585.txt
# P_1013.txt
# P_1775.txt
# P_1761.txt
# P_1397.txt
# P_190.txt
# P_147.txt
# P_1354.txt
# P_1383.txt
# P_184.txt
# P_1368.txt
# P_1432.txt
# P_1007.txt
# P_1793.txt
# P_1778.txt
# P_1022.txt
# P_1750.txt
# P_1744.txt
# P_1546.txt
# P_1234.txt
# P_972.txt
# P_1400.txt
# P_175.txt
# P_1399.txt
# P_1212.txt
# P_1560.txt
# P_940.txt
# P_1548.txt
# P_954.txt
# P_1574.txt
# P_1206.txt
# P_968.txt
# P_1012.txt
# P_1748.txt
# P_1006.txt
# P_981.txt
# P_765.txt
# P_1774.txt
# P_759.txt
# P_995.txt
# P_149.txt
# P_767.txt
# P_983.txt
# P_773.txt
# P_1789.txt
# P_1038.txt
# P_1004.txt
# P_1776.txt
# P_1762.txt
# P_1010.txt
# P_203.txt
# P_217.txt
# P_956.txt
# P_1210.txt
# P_163.txt
# P_177.txt
# P_1370.txt
# P_1576.txt
# P_188.txt
# P_1238.txt
# P_229.txt
# P_997.txt
# P_201.txt
# P_215.txt
# P_1614.txt
# P_1827.txt
# P_98.txt
# P_349.txt
# P_1833.txt
# P_73.txt
# P_1199.txt
# P_67.txt
# P_1760.txt
# P_771.txt
# P_1589.txt
# P_1204.txt
# P_1562.txt
# P_72.txt
# P_360.txt
# P_1173.txt
# P_1601.txt
# P_1167.txt
# P_1198.txt
# P_1615.txt
# P_1826.txt
# P_1416.txt
# P_942.txt
# P_1402.txt
# P_1364.txt
# P_1358.txt
# P_1172.txt
# P_1166.txt
# P_979.txt
# P_986.txt
# P_969.txt
# P_1549.txt
# P_1207.txt
# P_955.txt
# P_1575.txt
# P_1561.txt
# P_941.txt
# P_148.txt
# P_1798.txt
# P_206.txt
# P_1777.txt
# P_216.txt
# P_1005.txt
# P_996.txt
# P_1011.txt
# P_1039.txt
# P_202.txt
# P_1763.txt
# P_212.txt
# P_438.txt
# P_1401.txt
# P_1367.txt
# P_1415.txt
# P_58.txt
# P_1373.txt
# P_1429.txt
# P_1818.txt
# P_1788.txt
# P_982.txt
# P_772.txt
# P_1616.txt
# P_1165.txt
# P_1171.txt
# P_1158.txt
# P_1602.txt
# P_1617.txt
# P_1159.txt
# P_1170.txt
# P_766.txt
# P_1213.txt
# P_1398.txt
# P_160.txt
# P_612.txt
# P_174.txt
# P_1819.txt
# P_1414.txt
# P_439.txt
# P_1366.txt
# P_71.txt
# P_59.txt
# P_1428.txt
# P_1372.txt
# P_1824.txt
# P_70.txt
# P_64.txt
# P_1830.txt
# P_1164.txt
# P_1603.txt
# P_1831.txt
# P_65.txt
# P_1825.txt
# P_1002.txt
# P_1014.txt
# P_788.txt
# P_950.txt
# P_1000.txt
# P_987.txt
# P_978.txt
# P_993.txt
# P_763.txt
# P_1558.txt
# P_1772.txt
# P_1766.txt
# P_1613.txt
# P_1612.txt
# P_1809.txt
# P_1160.txt
# P_1174.txt
# P_49.txt
# P_429.txt
# P_1606.txt
# P_1570.txt
# P_1202.txt
# P_74.txt
# P_60.txt
# P_1820.txt
# P_1808.txt
# P_48.txt
# P_1377.txt
# P_1834.txt
# P_1411.txt
# P_1564.txt
# P_159.txt
# P_165.txt
# P_1410.txt
# P_1389.txt
# P_171.txt
# P_1362.txt
# P_1438.txt
# P_1376.txt
# P_944.txt
# P_75.txt
# P_1821.txt
# P_1835.txt
# P_1175.txt
# P_1388.txt
# P_1571.txt
# P_164.txt
# P_1565.txt
# P_1203.txt
# P_945.txt
# P_170.txt
# P_158.txt
# P_61.txt
# P_1161.txt
# P_1607.txt
# P_1767.txt
# P_992.txt
# P_1773.txt
# P_776.txt
# P_762.txt
# P_1029.txt
# P_1015.txt
# P_1001.txt
# P_428.txt
# P_1405.txt
# P_1363.txt
# P_819.txt
# P_1439.txt
# P_951.txt
# P_1559.txt
# P_760.txt
# P_1177.txt
# P_1604.txt
# P_1605.txt
# P_1163.txt
# P_1176.txt
# P_1611.txt
# P_88.txt
# P_1162.txt
# P_774.txt
# P_172.txt
# P_166.txt
# P_600.txt
# P_1407.txt
# P_1413.txt
# P_62.txt
# P_1836.txt
# P_1375.txt
# P_199.txt
# P_1188.txt
# P_1361.txt
# P_1349.txt
# P_1412.txt
# P_1189.txt
# P_1360.txt
# P_826.txt
# P_198.txt
# P_63.txt
# P_1406.txt
# P_1837.txt
# P_1822.txt
# P_76.txt
# P_358.txt
# P_749.txt
# P_1200.txt
# P_946.txt
# P_1566.txt
# P_1572.txt
# P_1214.txt
# P_985.txt
# P_991.txt
# P_1639.txt
# P_1610.txt
# P_1638.txt
# P_1823.txt
# P_359.txt
# P_77.txt
# P_1799.txt
# P_1764.txt
# P_1758.txt
# P_207.txt
# P_213.txt
# P_211.txt
# P_239.txt
# P_205.txt
# P_1374.txt
# P_1348.txt
# P_167.txt
# P_173.txt
# P_761.txt
# P_1599.txt
# P_1770.txt
# P_1016.txt
# P_1028.txt
# P_470.txt
# P_10.txt
# P_1663.txt
# P_1677.txt
# P_1105.txt
# P_464.txt
# P_1844.txt
# P_302.txt
# P_316.txt
# P_1688.txt
# P_1139.txt
# P_1138.txt
# P_1312.txt
# P_883.txt
# P_897.txt
# P_1474.txt
# P_101.txt
# P_1528.txt
# P_129.txt
# P_908.txt
# P_1662.txt
# P_39.txt
# P_11.txt
# P_303.txt
# P_471.txt
# P_1845.txt
# P_465.txt
# P_317.txt
# P_1689.txt
# P_1104.txt
# P_459.txt
# P_1676.txt
# P_1058.txt
# P_1299.txt
# P_288.txt
# P_1070.txt
# P_1716.txt
# P_1266.txt
# P_920.txt
# P_1064.txt
# P_1448.txt
# P_1306.txt
# P_840.txt
# P_1460.txt
# P_238.txt
# P_210.txt
# P_204.txt
# P_539.txt
# P_1771.txt
# P_1759.txt
# P_1003.txt
# P_1765.txt
# P_1272.txt
# P_934.txt
# P_1201.txt
# P_984.txt
# P_990.txt
# P_953.txt
# P_1567.txt
# P_1573.txt
# P_748.txt
# P_947.txt
# P_1514.txt
# P_1500.txt
# P_1702.txt
# P_277.txt
# P_263.txt
# P_505.txt
# P_1017.txt
# P_1598.txt
# P_314.txt
# P_300.txt
# P_12.txt
# P_1305.txt
# P_116.txt
# P_328.txt
# P_1311.txt
# P_1488.txt
# P_1463.txt
# P_1477.txt
# P_1339.txt
# P_1846.txt
# P_102.txt
# P_466.txt
# P_260.txt
# P_276.txt
# P_1703.txt
# P_1065.txt
# P_262.txt
# P_504.txt
# P_274.txt
# P_248.txt
# P_894.txt
# P_1729.txt
# P_1271.txt
# P_937.txt
# P_1503.txt
# P_1067.txt
# P_923.txt
# P_1701.txt
# P_1517.txt
# P_880.txt
# P_1259.txt
# P_1073.txt
# P_935.txt
# P_706.txt
# P_1273.txt
# P_1298.txt
# P_921.txt
# P_1267.txt
# P_1501.txt
# P_1515.txt
# P_1265.txt
# P_1715.txt
# P_506.txt
# P_1098.txt
# P_1717.txt
# P_1449.txt
# P_114.txt
# P_1313.txt
# P_1461.txt
# P_100.txt
# P_882.txt
# P_1307.txt
# P_1475.txt
# P_1071.txt
# P_289.txt
# P_1059.txt
# P_909.txt
# P_1529.txt
# P_896.txt
# P_128.txt
# P_38.txt
# P_458.txt
# P_463.txt
# P_305.txt
# P_1466.txt
# P_891.txt
# P_1314.txt
# P_1300.txt
# P_885.txt
# P_1472.txt
# P_1328.txt
# P_113.txt
# P_1072.txt
# P_249.txt
# P_1099.txt
# P_275.txt
# P_1714.txt
# P_261.txt
# P_507.txt
# P_1089.txt
# P_17.txt
# P_107.txt
# P_1499.txt
# P_1506.txt
# P_1704.txt
# P_1076.txt
# P_1512.txt
# P_1260.txt
# P_1062.txt
# P_1248.txt
# P_1274.txt
# P_932.txt
# P_1738.txt
# P_926.txt
# P_1270.txt
# P_936.txt
# P_881.txt
# P_1502.txt
# P_1258.txt
# P_1264.txt
# P_922.txt
# P_895.txt
# P_259.txt
# P_265.txt
# P_503.txt
# P_1476.txt
# P_301.txt
# P_1338.txt
# P_1310.txt
# P_1304.txt
# P_13.txt
# P_329.txt
# P_467.txt
# P_1700.txt
# P_271.txt
# P_1066.txt
# P_1516.txt
# P_1728.txt
# P_1675.txt
# P_1649.txt
# P_498.txt
# P_1674.txt
# P_1648.txt
# P_472.txt
# P_1661.txt
# P_499.txt
# P_103.txt
# P_117.txt
# P_1489.txt
# P_1462.txt
# P_1847.txt
# P_473.txt
# P_315.txt
# P_1106.txt
# P_919.txt
# P_138.txt
# P_892.txt
# P_1539.txt
# P_1288.txt
# P_266.txt
# P_1713.txt
# P_1061.txt
# P_1707.txt
# P_299.txt
# P_1049.txt
# P_272.txt
# P_500.txt
# P_884.txt
# P_112.txt
# P_1261.txt
# P_1301.txt
# P_1329.txt
# P_106.txt
# P_1498.txt
# P_890.txt
# P_1075.txt
# P_1088.txt
# P_270.txt
# P_264.txt
# P_1739.txt
# P_1249.txt
# P_1705.txt
# P_1077.txt
# P_1275.txt
# P_258.txt
# P_1711.txt
# P_1063.txt
# P_933.txt
# P_502.txt
# P_476.txt
# P_338.txt
# P_16.txt
# P_310.txt
# P_462.txt
# P_1842.txt
# P_1665.txt
# P_304.txt
# P_1513.txt
# P_927.txt
# P_1467.txt
# P_1664.txt
# P_477.txt
# P_1670.txt
# P_1102.txt
# P_311.txt
# P_339.txt
# P_1658.txt
# P_488.txt
# P_1507.txt
# P_853.txt
# P_1473.txt
# P_1315.txt
# P_1103.txt
# P_1671.txt
# P_489.txt
# P_1116.txt
# P_1843.txt
# P_267.txt
# P_1074.txt
# P_1060.txt
# P_1712.txt
# P_1538.txt
# P_1048.txt
# P_1706.txt
# P_298.txt
# P_1289.txt
# P_1302.txt
# P_1841.txt
# P_461.txt
# P_307.txt
# P_313.txt
# P_475.txt
# P_15.txt
# P_1464.txt
# P_273.txt
# P_918.txt
# P_1262.txt
# P_1672.txt
# P_1100.txt
# P_1667.txt
# P_1666.txt
# P_1101.txt
# P_1673.txt
# P_1115.txt
# P_28.txt
# P_924.txt
# P_887.txt
# P_105.txt
# P_111.txt
# P_930.txt
# P_893.txt
# P_1510.txt
# P_139.txt
# P_1276.txt
# P_1504.txt
# P_878.txt
# P_1458.txt
# P_1316.txt
# P_312.txt
# P_1303.txt
# P_1840.txt
# P_1471.txt
# P_1465.txt
# P_1317.txt
# P_460.txt
# P_474.txt
# P_1699.txt
# P_1470.txt
# P_449.txt
# P_29.txt
# P_931.txt
# P_1277.txt
# P_925.txt
# P_110.txt
# P_1263.txt
# P_1505.txt
# P_104.txt
# P_1511.txt
# P_1128.txt
# P_448.txt
# P_306.txt
# P_14.txt
# P_1698.txt
# P_1459.txt
# P_879.txt
# P_886.txt
# P_1284.accented.txt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-220925672c1d> in <module>()
#       2   for f in files:
#       3     print(f)
# ----> 4     accent.write_file([os.path.join(path, f)])
#
# /usr/local/lib/python3.7/dist-packages/ru_accent_poet/__init__.py in write_file(files)
#      31             with open(re.sub(r'\.(?=[^.]+$)', '.accented.', file), 'w', encoding='utf-8') as file_write:
#      32                 for line in clear_file:
# ---> 33                     file_write.write(accent_line(line) + '\n')
#      34
#      35
#
# /usr/local/lib/python3.7/dist-packages/ru_accent_poet/__init__.py in accent_line(line)
#      11     words = line.split()
#      12     words_rule = accent_line_rules(line).split()
# ---> 13     words_nacc = accent.put_stress(line).split()
#      14     for j in range(len(words)):
#      15         voc = re.findall('[аеиоуыэюяёАЕИОУЫЭЮЯЁ]', words[j])
#
# /usr/local/lib/python3.7/dist-packages/russtress/text_accentAPI.py in put_stress(self, text, stress_symbol)
#      57                 pass
#      58             else:
# ---> 59                 accented_phrase.append(self._predict(w))
#      60         final = []
#      61
#
# /usr/local/lib/python3.7/dist-packages/russtress/text_accentAPI.py in _predict(self, word)
#      28         for index, letter in enumerate(word):
#      29             pos = MAXLEN - len(word.replace("'", "")) + index
# ---> 30             x[0, pos, CHAR_INDICES[letter]] = 1
#      31         preds = self.model.predict(x, verbose=0)[0]
#      32         preds = preds.tolist()
#
# IndexError: index 40 is out of bounds for axis 1 with size 40
